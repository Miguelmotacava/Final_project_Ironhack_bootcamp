# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import pandas as pd
import time
import warnings
import pymongo
import json
warnings.filterwarnings('ignore')

# %%
from funciones_def import *

# %%
client = pymongo.MongoClient("mongodb+srv://miguelmotacava:Mmcmmc164@proyectofifa.qbief4y.mongodb.net/test")

# %%
try :
    db = client.fifa23
    colec = db.price_players3
except:
    pass

# %%
while 1==1:
#for i in range(1):
    try:
        dicfinal = {'names':[], 'version':[], 'med': [],'time':[], 'price':[]}

        for i in range(660):
            print(f'iteracion {i}')
            url = f'https://www.futwiz.com/en/fifa23/players?page={i}'
            dic = scrap_precios_console(url)

            dicfinal['names'] = dicfinal['names']+dic['names']
            dicfinal['version'] = dicfinal['version']+dic['version']
            dicfinal['price'] = dicfinal['price']+dic['price']
            dicfinal['time'] = dicfinal['time']+dic['time']
            dicfinal['med'] = dicfinal['med']+dic['med']
            
            print(dicfinal['time'][-1])
            
            
        with open(f'price.json', 'w') as fp:
            json.dump(dicfinal, fp)

        df_final = pd.read_json(f'price.json')
        df_final['time']=pd.to_datetime(df_final['time'])
        df_final['med']=df_final['med'].astype('int16')
        df_final['price']=df_final['price'].astype('float64')
        
        db.price_players3.insert_many(df_final.apply(lambda x: x.to_dict(), axis=1).to_list())
    
    except:
        continue
# Out:
# iteracion 0
# Thu Oct  6 23:39:47 2022
# iteracion 1
# Thu Oct  6 23:39:50 2022
# iteracion 2
# Thu Oct  6 23:39:54 2022
# iteracion 3
# Thu Oct  6 23:39:58 2022
# iteracion 4
# Thu Oct  6 23:40:02 2022
# iteracion 5
# Thu Oct  6 23:40:06 2022
# iteracion 6
# Thu Oct  6 23:40:10 2022
# iteracion 7
# Thu Oct  6 23:40:14 2022
# iteracion 8
# Thu Oct  6 23:40:18 2022
# iteracion 9
# Thu Oct  6 23:40:22 2022
# iteracion 10
# Thu Oct  6 23:40:26 2022
# iteracion 11
# Thu Oct  6 23:40:30 2022
# iteracion 12
# Thu Oct  6 23:40:35 2022
# iteracion 13
# Thu Oct  6 23:40:41 2022
# iteracion 14
# Thu Oct  6 23:40:47 2022
# iteracion 15
# Thu Oct  6 23:40:51 2022
# iteracion 16
# Thu Oct  6 23:40:57 2022
# iteracion 17
# Thu Oct  6 23:41:01 2022
# iteracion 18
# Thu Oct  6 23:41:05 2022
# iteracion 19
# Thu Oct  6 23:41:09 2022
# iteracion 20
# Thu Oct  6 23:41:14 2022
# iteracion 21
# Thu Oct  6 23:41:18 2022
# iteracion 22
# Thu Oct  6 23:41:23 2022
# iteracion 23
# Thu Oct  6 23:41:28 2022
# ...

# %%
for i,j in dicfinal.items():
    print(i)
    print(len(j))

# %%
pd.DataFrame(dicfinal)

# %%
#db.price_players.insert_many(df_final.apply(lambda x: x.to_dict(), axis=1).to_list())

# %%
#db.price_players.insert_many(df_final.apply(lambda x: x.to_dict(), axis=1).to_list())
